# %%
from rosam.model import models
from rosam.utils import aux
import numpy as np
import matplotlib.pyplot as plt

# %%
a= aux.plot_w_bckgrnd()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 C = rosam.model.models.CcaSR()
#       2 a = aux.repetitive_stim_maker()
#
# TypeError: CcaSR.__init__() missing 2 required positional arguments: 'params' and 't_max'
