# %%
from aisam.utils.aux import config_generator

# %%
params = {}
params['delta'] = 0.01
params['alpha'] = 0.1
params['beta'] = 1
params['k'] = 0.4851
params['k_tet'] = 5
params['h1'] = 2.3435*0.0303
params['h2'] = 0.0303
params['tau_delay'] = 12
params['n']=3.6
params['n_tet'] = 2
params['c2'] = 0.0631

# %%
config_generator('ccasr','/Users/hossein/Documents/Projects/AISAM/assets/260504',960,10,5,1000,3,params=params)
# Out:
# (PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/260504/config.json'),
#  {'circuit': 'ccasr',
#   'label': 'ccasr',
#   't_max': 960,
#   'sampling': 10,
#   'num_cells': 1000,
#   'num_realizations': 3,
#   'root_folder': '/Users/hossein/Documents/Projects/AISAM/assets/260504/',
#   'params': {'delta': 0.01,
#    'alpha': 0.1,
#    'beta': 1,
#    'k': 0.4851,
#    'k_tet': 5,
#    'h1': 0.07100805,
#    'h2': 0.0303,
#    'tau_delay': 12,
#    'n': 3.6,
#    'n_tet': 2,
#    'c2': 0.0631,
#    't_max': 960,
#    'sampling': 10},
#   'circuit_parameters': {'delta': 0.01,
#    'alpha': 0.1,
#    'beta': 1,
#    'k': 0.4851,
#    'k_tet': 5,
#    'h1': 0.07100805,
#    'h2': 0.0303,
#    'tau_delay': 12,
#    'n': 3.6,
#    'n_tet': 2,
#    'c2': 0.0631,
#    't_max': 960,
#    'sampling': 10},
#   'interval_rate': 5,
#   'params_path': '/Users/hossein/Documents/Projects/AISAM/assets/260504/simulation_params.json'})

# %%
from aisam.utils import training
import numpy

training.training("/Users/hossein/Documents/Projects/AISAM/assets/260504/config.json")
# Out:
# {'run_dir': PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/training_data/ccasr_2026-05-04_13-14-48'),
#  'simulation_path': PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/training_data/ccasr_2026-05-04_13-14-48/simulation.pkl'),
#  'params_path': PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/training_data/ccasr_2026-05-04_13-14-48/simulation_params.json'),
#  'stims_path': PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/training_data/ccasr_2026-05-04_13-14-48/stims.json'),
#  'config_path': PosixPath('/Users/hossein/Documents/Projects/AISAM/assets/training_data/ccasr_2026-05-04_13-14-48/config.json'),
#  'config': {'created_at': '2026-05-04_13-14-48',
#   'circuit': 'ccasr',
#   'circuit_parameters': {'delta': 0.01,
#    'alpha': 0.1,
#    'beta': 1,
#    'k': 0.4851,
#    'k_tet': 5,
#    'h1': 0.07100805,
#    'h2': 0.0303,
#    'tau_delay': 12,
#    'n': 3.6,
#    'n_tet': 2,
#    'c2': 0.0631,
#    't_max': 960,
#    'sampling': 10},
# ...
